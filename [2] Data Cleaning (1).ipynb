# %%
campers.ipv <- read.csv("/work/campers_ipv.csv")

# %% [markdown]
# Important Demographics:
#
# V012	Respondent's current age
# V013	Age in 5-year groups
# V024	Region
# V106	Highest educational level
# V149	Educational attainment
#
# V501	Current marital status
# V502	Currently/formerly/never in union
#
# V701	Husband/partner's education level
# V704	Husband/partner's occupation
# V705	Husband/partner's occupation (grouped)
# V714	Respondent currently working
# V716	Respondent's occupation
# V717	Respondent's occupation (grouped)
# V729	Husband/partner's educational attainment
# V730	Husband/partner's age
# V731	Respondent worked in last 12 months

# %%
# Remove rows with missing important demographics since they may
# be attributed to measurement or recording errors

demographics <- c("V012", "V013", "V024", "V106","V149", "V501", "V502", "V701", "V704", "V705", 
"V714", "V716", "V717", "V729", "V730", "V731")

# %%
campers.ipv.clean <- campers.ipv[complete.cases(campers.ipv[, demographics]), ]

# %%
# measure how many data were removed

nrow(campers.ipv)
nrow(campers.ipv.clean)
# Out:
# [1] 14919
# [1] 14311

# %% [markdown]
# ##### V106_VS1	Highest educational level
# 		No education	0
# 		Primary	1
# 		Secondary	2
# 		Higher	3
# 		Don't know	8
# 		Missing	9		Missing
#
# ##### V501_VS1	Current marital status
# 		Never in union	0
# 		Married	1
# 		Living with partner	2
# 		Widowed	3
# 		Divorced	4
# 		No longer living together/separated	5
# 		Missing	9		Missing
#
# ##### V701_VS1	Husband/partner's education level
# 		No education	0
# 		Primary	1
# 		Secondary	2
# 		Higher	3
# 		Don't know	8
# 		Missing	9		Missing
# 		Not applicable	 		Not Applicable
#
# ##### V704_VS1	Husband/partner's occupation
# 		Not working and didn't work in last 12 months	0
# 			1	9995
# 		Other	9996
# 		Don't know	9998
# 		Missing	9999		Missing
# 		Not applicable	    		Not Applicable
#
# ##### V716_VS1	Respondent's occupation
# 		Not working and didn't work in last 12 months	0
# 			1	9995
# 		Other	9996
# 		Don't know	9998
# 		Missing	9999		Missing
# 		Not applicable	    		Not Applicable
#
# ##### V730_VS1	Husband/partner's age
# 			15	95
# 		96+	96
# 			97
# 		Don't know	98
# 		Missing	99		Missing
# 		Not applicable	  		Not Applicable

# %%
# Remove rows with values of variables categorized as 'missing' or 'don't know' 
# since they provide incomplete information, and therefore may affect accuracy of estimates

campers.ipv.final.data <- campers.ipv.clean[
    campers.ipv.clean$V106 < 8 &
    campers.ipv.clean$V501 < 9 &
    campers.ipv.clean$V701 < 8 &
    campers.ipv.clean$V704 < 9998 &
    campers.ipv.clean$V716 < 9998 &
    campers.ipv.clean$V730 < 98,
    -c(1)
]

# %%
# measure how many data were removed

nrow(campers.ipv)
nrow(campers.ipv.clean)
nrow(campers.ipv.final.data)
ncol(campers.ipv.final.data)

# Final Number of Observations: 14232 women respondents
# Out:
# [1] 14919
# [1] 14311
# [1] 14232
# [1] 115

# %%
View(campers.ipv.final.data)
# Out:
#       CASEID          V000 V001 V002 V003 V004 V005    V006 V007 V008 ... D114
# 1     2               PH5  1     1    2   1    1446345 8    2008 1304 ...  1
# 2     2               PH5  1     3    2   1    1446345 8    2008 1304 ...  1
# 3     2               PH5  1     4    2   1    1446345 8    2008 1304 ... NA
# 4     2               PH5  1     6    2   1    1446345 8    2008 1304 ...  2
# 5     2               PH5  2     5    2   2    1191053 8    2008 1304 ...  1
# 6     6               PH5  2     7    6   2    1191053 8    2008 1304 ...  2
# 14909     12490020  2 PH7  1249 20    2   1249  872595 9    2017 1413 ... NA
# 14910     12500002  2 PH7  1250  2    2   1250 1227087 8    2017 1412 ...  2
# 14911     12500006  2 PH7  1250  6    2   1250 1227087 8    2017 1412 ...  1
# 14912     12500009  2 PH7  1250  9    2   1250 1227087 8    2017 1412 ... NA
# 14913     12500012  2 PH7  1250 12    2   1250 1227087 8    2017 1412 ... NA
# 14914     12500016  2 PH7  1250 16    2   1250 1227087 8    2017 1412 ... NA
# 14915     12500018  2 PH7  1250 18    2   1250 1227087 8    2017 1412 ...  2
# 14916     12500020  2 PH7  1250 20    2   1250 1227087 8    2017 1412 ...  2
# 14917     12500022  2 PH7  1250 22    2   1250 1227087 8    2017 1412 ...  2
# 14918     12500024  2 PH7  1250 24    2   1250 1227087 8    2017 1412 ... NA
# 14919     12500026  2 PH7  1250 26    2   1250 1227087 8    2017 1412 ...  2
#       V745A.x V745B.x V008A V704A V745A.y V745B.y V745C V745D D103G
# 1     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 2     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 3     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 4     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 5     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 6     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 7     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 8     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 9     NA      NA      NA    NA    NA      NA      NA    NA    NA
# 10    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 11    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 12    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 13    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 14    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 15    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 16    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 17    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 18    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 19    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 20    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 21    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 22    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 23    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 24    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 25    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 26    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 27    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 28    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 29    NA      NA      NA    NA    NA      NA      NA    NA    NA
# 31    NA      NA      NA    NA    NA      NA      NA    NA    NA
# ...   ...     ...     ...   ...   ...     ...     ...   ...   ...
# 14890 NA      NA      42979 1     2       0       NA    NA     0
# 14891 NA      NA      42977 1     0       0       NA    NA     0
# 14892 NA      NA      42999 1     2       0       NA    NA     0
# 14893 NA      NA      42999 1     2       2       NA    NA     0
# 14894 NA      NA      43000 1     3       0       NA    NA     0
# 14895 NA      NA      43000 1     0       0       NA    NA     0
# 14896 NA      NA      42999 1     2       2       NA    NA     0
# 14897 NA      NA      43000 1     2       3       NA    NA     0
# 14898 NA      NA      42999 1     2       2       NA    NA     0
# 14899 NA      NA      42999 1     2       0       NA    NA     0
# 14900 NA      NA      42990 1     0       0       NA    NA     0
# 14901 NA      NA      42990 1     0       0       NA    NA    NA
# 14902 NA      NA      42991 1     0       0       NA    NA    NA
# 14903 NA      NA      42991 1     2       2       NA    NA     0
# 14904 NA      NA      42997 1     0       0       NA    NA    NA
# 14905 NA      NA      42997 1     2       0       NA    NA     0
# 14906 NA      NA      42996 1     2       2       NA    NA     0
# 14907 NA      NA      42996 2     2       0       NA    NA     0
# 14908 NA      NA      42996 1     0       2       NA    NA     0
# 14909 NA      NA      42996 1     2       0       NA    NA     0
# 14910 NA      NA      42971 1     2       2       NA    NA     0
# 14911 NA      NA      42970 1     0       2       NA    NA     0
# 14912 NA      NA      42970 1     2       2       NA    NA     0
# 14913 NA      NA      42970 1     3       0       NA    NA     0
# 14914 NA      NA      42970 1     2       2       NA    NA     0
# 14915 NA      NA      42970 1     2       2       NA    NA     0
# 14916 NA      NA      42970 1     2       2       NA    NA     0
# 14917 NA      NA      42969 1     0       0       NA    NA     0
# 14918 NA      NA      42969 1     2       0       NA    NA     0
# 14919 NA      NA      42971 1     2       1       NA    NA     0

# %%
write.csv(campers.ipv.final.data, "/work/campers_ipv_final_data.csv")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8672f010-76e5-4fe5-a087-2513d801c0e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
