# %%
ipv <- read.csv("campers_ipv_for_analysis_corrected_match.csv")
 
# descriptives
aggregate(ipv$Counts.IPV, list(ipv$Husb.Employment.Bin), FUN = mean) # pinakamataas female only
aggregate(ipv$Counts.IPV, list(ipv$Husb.Employment.Bin), FUN = sum) # pinakamataas male only and both employed
aggregate(ipv$Counts.IPV, list(ipv$Husb.Employment.Bin), FUN = var)
aggregate(ipv$Counts.IPV, list(ipv$Husb.Employment.Bin), FUN = lengh)
summary(ipv)
table(ipv$Counts.IPV) # many zeros

# reclassifying variables
ipv$Marital <- factor(ipv$Marital)
ipv$Husb.Educ.Level <- factor(ipv$Husb.Educ.Level)
ipv$Educ.Level <- factor(ipv$Educ.Level)
ipv$Region <- factor(ipv$Region)
ipv$LPG <- relevel(factor(ipv$LPG), ref = "Male only Employed")
# Out:
#   Group.1 x
# 1 0       0.3452381
# 2 1       0.3387253
#   Group.1 x
# 1 0         29
# 2 1       1403
#   Group.1 x
# 1 0       0.5179289
# 2 1       0.4563556
#   Group.1 x
# 1 0         84
# 2 1       4142
#       X.1             X          RespondentID        Year           Age
#  Min.   :   1   Min.   : 9224   Min.   : 9719   Min.   :2017   Min.   :16.00
#  1st Qu.:1057   1st Qu.:10486   1st Qu.:11034   1st Qu.:2017   1st Qu.:24.00
#  Median :2114   Median :11742   Median :12353   Median :2017   Median :29.00
#  Mean   :2114   Mean   :11744   Mean   :12343   Mean   :2017   Mean   :29.51
#  3rd Qu.:3170   3rd Qu.:13023   3rd Qu.:13668   3rd Qu.:2017   3rd Qu.:34.00
#  Max.   :4226   Max.   :14232   Max.   :14919   Max.   :2017   Max.   :49.00
#
#      Region         Educ.Level      Educ.Years    Educ.Attained
#  Min.   : 1.000   Min.   :0.000   Min.   : 0.00   Min.   :0.000
#  1st Qu.: 5.000   1st Qu.:2.000   1st Qu.: 8.00   1st Qu.:3.000
# ...

# %%
# descriptives
aggregate(ipv$Counts.IPV, list(ipv$Employment.Bin), FUN = mean) # pinakamataas female only
aggregate(ipv$Counts.IPV, list(ipv$Employment.Bin), FUN = sum) # pinakamataas male only and both employed
aggregate(ipv$Counts.IPV, list(ipv$Employment.Bin), FUN = var)
aggregate(ipv$Counts.IPV, list(ipv$Employment.Bin), FUN = length)
# Out:
#   Group.1 x
# 1 0       0.3296837
# 2 1       0.3517045
#   Group.1 x
# 1 0       813
# 2 1       619
#   Group.1 x
# 1 0       0.4433944
# 2 1       0.4771432
#   Group.1 x
# 1 0       2466
# 2 1       1760

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8672f010-76e5-4fe5-a087-2513d801c0e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
