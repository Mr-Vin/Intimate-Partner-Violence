# %% [markdown]
# # Data Analysis Codes

# %%
### Final Data Ready for Propensity Score Matching:   "/work/campers_ipv_for_analysis_corrected.csv"

ipv3 <- read.csv("campers_ipv_for_analysis_corrected_match_wealth.csv")
colnames(ipv3)
# Out:
#  [1] "X.1"                 "X"                   "RespondentID"
#  [4] "Year"                "Age"                 "Region"
#  [7] "Educ.Level"          "Educ.Years"          "Educ.Attained"
# [10] "Wealth.Index"        "Wealth.Index.Rural"  "Marital"
# [13] "Husb.Educ.Level"     "Husb.Educ.Years"     "Husb.Employment"
# [16] "Employment"          "Husb.Educ.Attained"  "Husb.Age"
# [19] "Emotional.IPV"       "Less.Physic.IPV"     "More.Physic.IPV"
# [22] "Sexual.IPV"          "Husb.Employment.Bin" "Employment.Bin"
# [25] "LPG"                 "Physical.IPV"        "ANY.IPV"
# [28] "Counts.IPV"          "Male"                "Female"

# %%
library(fastDummies)

ipv3$Marital <- factor(ipv3$Marital)
ipv3$Husb.Educ.Level <- factor(ipv3$Husb.Educ.Level)
ipv3$Educ.Level <- factor(ipv3$Educ.Level)
ipv3$Region <- factor(ipv3$Region)
ipv3$Wealth.Index <- factor(ipv3$Wealth.Index)

ipv3 <- dummy_cols(ipv3)
ipv3
colnames(ipv3)
# Out:
#      X.1  X    RespondentID Year Age Region Educ.Level Educ.Years Educ.Attained
# 1     1    1    1           2017 30  15     2           8         3
# 2     2    2    2           2017 40  15     2          10         3
# 3     3    3    3           2017 19  15     1           6         1
# 4     4    6    7           2017 23  15     3          12         5
# 5     5    7    8           2017 30  15     1           7         2
# 6     6    8    9           2017 19  15     2           9         3
# 7     7    9   10           2017 32  15     2          11         4
# 8     8   10   11           2017 37  15     1           2         1
# 9     9   11   12           2017 42  15     2          11         4
# 10   10   12   13           2017 23  15     2          10         3
# 11   11   13   14           2017 24  15     1           7         2
# 12   12   14   15           2017 28  15     3          12         5
# 13   13   15   16           2017 27  15     3          15         5
# ...

# %% [markdown]
# ## Matching

# %% [markdown]
# Path # 1 - Treatment = Male

# %%
install.packages(c("Matching","rgenoud","MatchIt"))
library(MatchIt)
m.out.2 <- matchit(
  Husb.Employment.Bin ~ Age + Region_2 + Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 + Region_10
                            + Region_11 + Region_12 + Region_13 + Region_14 + Region_15 + Region_16 + Region_17
                            + Educ.Level_1 + Educ.Level_2 + Educ.Level_3 + Marital_2 
                            + Husb.Educ.Level_1 + Husb.Educ.Level_2 + Husb.Educ.Level_3
                            + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 + Wealth.Index_4,
                            
  data = ipv3,
  method = "cem",
  distance = "glm",
  link = "logit",
  ratio=1)

summary(m.out.2)
ipv_match.2 <- match.data(m.out.2)

names(m.out.2)
# Out:
# Installing packages into ‘/work/.R/library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages(c("Matching", "rgenoud", "MatchIt")):
# “installation of package ‘Matching’ had non-zero exit status”
# Warning message in install.packages(c("Matching", "rgenoud", "MatchIt")):
# “installation of package ‘rgenoud’ had non-zero exit status”
# Warning message in install.packages(c("Matching", "rgenoud", "MatchIt")):
# “installation of package ‘MatchIt’ had non-zero exit status”
# Call:
# matchit(formula = Husb.Employment.Bin ~ Age + Region_2 + Region_3 +
#     Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 +
#     Region_10 + Region_11 + Region_12 + Region_13 + Region_14 +
#     Region_15 + Region_16 + Region_17 + Educ.Level_1 + Educ.Level_2 +
#     Educ.Level_3 + Marital_2 + Husb.Educ.Level_1 + Husb.Educ.Level_2 +
#     Husb.Educ.Level_3 + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 +
# ...

# %%
plot(summary(m.out.2),
     var.order = "unmatched", abs = FALSE)
# Out:
# plot without title

# %%
m.out.3 <- matchit(
  Employment.Bin ~ Age + Region_2 + Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 + Region_10
                            + Region_11 + Region_12 + Region_13 + Region_14 + Region_15 + Region_16 + Region_17 
                            + Educ.Level_1 + Educ.Level_2 + Educ.Level_3 + Marital_2
                            + Husb.Educ.Level_1 + Husb.Educ.Level_2 + Husb.Educ.Level_3
                            + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 + Wealth.Index_4,
  data = ipv_match.2,
  method = "cem",
  distance = "glm",
  link = "logit",
  ratio=1)

ipv_match.3 <- match.data(m.out.3,  weights = "wts", subclass = "sub2")
summary(m.out.3)
unique(ipv_match.3$Region)
unique(ipv_match.3$Husb.Educ.Level)
nrow(ipv_match.3)
# Out:
# Call:
# matchit(formula = Employment.Bin ~ Age + Region_2 + Region_3 +
#     Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 +
#     Region_10 + Region_11 + Region_12 + Region_13 + Region_14 +
#     Region_15 + Region_16 + Region_17 + Educ.Level_1 + Educ.Level_2 +
#     Educ.Level_3 + Marital_2 + Husb.Educ.Level_1 + Husb.Educ.Level_2 +
#     Husb.Educ.Level_3 + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 +
#     Wealth.Index_4, data = ipv_match.2, method = "cem", distance = "glm",
#     link = "logit", ratio = 1)
#
# Summary of Balance for All Data:
#                   Means Treated Means Control Std. Mean Diff. Var. Ratio
# Age                     30.3333       27.3559          0.4430     1.2874
# Region_2                 0.0667        0.0000          0.2673          .
# Region_3                 0.2222        0.1186          0.2491          .
# Region_4                 0.0667        0.1017         -0.1404          .
# ...

# %%
plot(summary(m.out.3),
     var.order = "unmatched", abs = FALSE)
# Out:
# plot without title

# %%
m.out.4 <- matchit(
  Employment.Bin ~ Age + Region_2 + Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 + Region_10
                            + Region_11 + Region_12 + Region_13 + Region_14 + Region_15 + Region_16 + Region_17 
                            + Educ.Level_1 + Educ.Level_2 + Educ.Level_3 + Marital_2
                            + Husb.Educ.Level_1 + Husb.Educ.Level_2 + Husb.Educ.Level_3
                            + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 + Wealth.Index_4,
  data = ipv3,
  method = "cem",
  distance = "glm",
  link = "logit",
  ratio=1)

summary(m.out.4)
ipv_match.4 <- match.data(m.out.4)
# Out:
# Call:
# matchit(formula = Employment.Bin ~ Age + Region_2 + Region_3 +
#     Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 +
#     Region_10 + Region_11 + Region_12 + Region_13 + Region_14 +
#     Region_15 + Region_16 + Region_17 + Educ.Level_1 + Educ.Level_2 +
#     Educ.Level_3 + Marital_2 + Husb.Educ.Level_1 + Husb.Educ.Level_2 +
#     Husb.Educ.Level_3 + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 +
#     Wealth.Index_4, data = ipv3, method = "cem", distance = "glm",
#     link = "logit", ratio = 1)
#
# Summary of Balance for All Data:
#                   Means Treated Means Control Std. Mean Diff. Var. Ratio
# Age                     30.8778       28.5276          0.3635     1.0297
# Region_2                 0.0466        0.0312          0.0729          .
# Region_3                 0.0670        0.0795         -0.0497          .
# Region_4                 0.0568        0.0580         -0.0051          .
# ...

# %%
plot(summary(m.out.4),
     var.order = "unmatched", abs = FALSE)
# Out:
# plot without title

# %%
m.out.5 <- matchit(
  Husb.Employment.Bin ~ Age + Region_2 + Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 + Region_10
                            + Region_11 + Region_12 + Region_13 + Region_14 + Region_15 + Region_16 + Region_17 
                            + Educ.Level_1 + Educ.Level_2 + Educ.Level_3 + Marital_2
                            + Husb.Educ.Level_1 + Husb.Educ.Level_2 + Husb.Educ.Level_3
                            + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 + Wealth.Index_4, 
  data = ipv_match.4,
  method = "cem",
  distance = "glm",
  link = "logit",
  ratio=1)

ipv_match.5 <- match.data(m.out.5,  weights = "wts", subclass = "sub2")
summary(m.out.5)
unique(ipv_match.5$Region)
unique(ipv_match.5$Husb.Educ.Level)
nrow(ipv_match.5)
# Out:
# Call:
# matchit(formula = Husb.Employment.Bin ~ Age + Region_2 + Region_3 +
#     Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 +
#     Region_10 + Region_11 + Region_12 + Region_13 + Region_14 +
#     Region_15 + Region_16 + Region_17 + Educ.Level_1 + Educ.Level_2 +
#     Educ.Level_3 + Marital_2 + Husb.Educ.Level_1 + Husb.Educ.Level_2 +
#     Husb.Educ.Level_3 + Wealth.Index_1 + Wealth.Index_2 + Wealth.Index_3 +
#     Wealth.Index_4, data = ipv_match.4, method = "cem", distance = "glm",
#     link = "logit", ratio = 1)
#
# Summary of Balance for All Data:
#                   Means Treated Means Control Std. Mean Diff. Var. Ratio
# Age                     28.9373         29.30         -0.0640     0.6752
# Region_2                 0.0261          0.00          0.1638          .
# Region_3                 0.0709          0.25         -0.6974          .
# Region_4                 0.0471          0.15         -0.4862          .
# ...

# %%
plot(summary(m.out.5),
     var.order = "unmatched", abs = FALSE, )
# Out:
# plot without title

# %%
colnames(ipv_match.3)
unique(ipv_match.3$Region)
unique(ipv_match.3$Marital)
unique(ipv_match.3$Educ.Level)
unique(ipv_match.3$Husb.Educ.Level)
unique(ipv_match.3$Wealth.Index)
nrow(ipv_match.3)
# Out:
#  [1] "X.1"                      "X"
#  [3] "RespondentID"             "Year"
#  [5] "Age"                      "Region"
#  [7] "Educ.Level"               "Educ.Years"
#  [9] "Educ.Attained"            "Wealth.Index"
# [11] "Wealth.Index.Rural"       "Marital"
# [13] "Husb.Educ.Level"          "Husb.Educ.Years"
# [15] "Husb.Employment"          "Employment"
# [17] "Husb.Educ.Attained"       "Husb.Age"
# [19] "Emotional.IPV"            "Less.Physic.IPV"
# [21] "More.Physic.IPV"          "Sexual.IPV"
# [23] "Husb.Employment.Bin"      "Employment.Bin"
# [25] "LPG"                      "Physical.IPV"
# [27] "ANY.IPV"                  "Counts.IPV"
# [29] "Male"                     "Female"
# [31] "Region_1"                 "Region_2"
# [33] "Region_3"                 "Region_4"
# [35] "Region_5"                 "Region_6"
# [37] "Region_7"                 "Region_8"
# [39] "Region_9"                 "Region_10"
# [41] "Region_11"                "Region_12"
# ...

# %%
ipv.M.pois <- glm(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + (Husb.Employment.Bin * Employment.Bin) + Age
                            + Region_4 + Region_5  + Region_8 + Region_9 + Region_10
                            + Region_13 + Region_15
                            + Educ.Level_2 + Educ.Level_3 + Marital_2
                            + Husb.Educ.Level_1 
                            + Wealth.Index_2*Employment.Bin + Wealth.Index_3*Employment.Bin + Wealth.Index_4*Employment.Bin,
                        family = poisson, weights = wts, data = ipv_match.3)
summary(ipv.M.pois)
# Out:
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# Call:
# glm(formula = Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
#     (Husb.Employment.Bin * Employment.Bin) + Age + Region_4 +
#     Region_5 + Region_8 + Region_9 + Region_10 + Region_13 +
#     Region_15 + Educ.Level_2 + Educ.Level_3 + Marital_2 + Husb.Educ.Level_1 +
#     Wealth.Index_2 * Employment.Bin + Wealth.Index_3 * Employment.Bin +
#     Wealth.Index_4 * Employment.Bin, family = poisson, data = ipv_match.3,
#     weights = wts)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.27678  -0.00002  -0.00001  -0.00001   0.68316
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                        -1.785e+01  1.433e+05   0.000    1.000
# Husb.Employment.Bin                -3.410e-01  3.061e+04   0.000    1.000
# Employment.Bin                      2.180e-01  3.907e+04   0.000    1.000
# ...

# %%
#Pseudo R^2
1-(4.1991/36.6797)
# Out:
# [1] 0.8855198

# %%
# Deviance Goodness-of-Fit Test
pchisq(ipv.M.pois$deviance, df = ipv.M.pois$df.residual, lower.tail = FALSE)
# Out:
# [1] 1

# %%
library(regclass)

VIF(ipv.M.pois)
# Out:
# Loading required package: bestglm
#
# Loading required package: leaps
#
# Loading required package: VGAM
#
# Loading required package: stats4
#
# Loading required package: splines
#
# Loading required package: rpart
#
# Loading required package: randomForest
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
# Important regclass change from 1.3:
# All functions that had a . in the name now have an _
# all.correlations -> all_correlations, cor.demo -> cor_demo, etc.
# Error in h(simpleError(msg, call)): error in evaluating the argument 'object' in selecting a method for function 'coef': object 'ipv.M.pois' not found
# Traceback:
#
# 1. VIF(ipv.M.pois)
# 2. coef(mod)
# 3. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "object 'ipv.M.pois' not found",
#  .     base::quote(coef(mod)))
# 4. h(simpleError(msg, call))

# %%
#install.packages('pscl')
#library(pscl)

#pR2(ipv.M.pois)['McFadden'] #i cant make it work sorry

#McFadden Pseudo R^2
1-(121.82/202.46)
# Out:
# [1] 0.3983009

# %%
colnames(ipv_match.5)
unique(ipv_match.5$Region)
unique(ipv_match.5$Marital)
unique(ipv_match.5$Educ.Level)
unique(ipv_match.5$Husb.Educ.Level)
unique(ipv_match.5$Wealth.Index)
# Out:
#  [1] "X.1"                      "X"
#  [3] "RespondentID"             "Year"
#  [5] "Age"                      "Region"
#  [7] "Educ.Level"               "Educ.Years"
#  [9] "Educ.Attained"            "Wealth.Index"
# [11] "Wealth.Index.Rural"       "Marital"
# [13] "Husb.Educ.Level"          "Husb.Educ.Years"
# [15] "Husb.Employment"          "Employment"
# [17] "Husb.Educ.Attained"       "Husb.Age"
# [19] "Emotional.IPV"            "Less.Physic.IPV"
# [21] "More.Physic.IPV"          "Sexual.IPV"
# [23] "Husb.Employment.Bin"      "Employment.Bin"
# [25] "LPG"                      "Physical.IPV"
# [27] "ANY.IPV"                  "Counts.IPV"
# [29] "Male"                     "Female"
# [31] "Region_1"                 "Region_2"
# [33] "Region_3"                 "Region_4"
# [35] "Region_5"                 "Region_6"
# [37] "Region_7"                 "Region_8"
# [39] "Region_9"                 "Region_10"
# [41] "Region_11"                "Region_12"
# ...

# %%
 ipv.M.pois.2 <- glm(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + (Husb.Employment.Bin * Employment.Bin) + Age
                            + Region_4 + Region_5 + Region_9 + Region_10
                            + Region_12 + Region_13 + Region_15
                            + Educ.Level_2 + Educ.Level_3 + Marital_2
                            + Husb.Educ.Level_1 
                            + Wealth.Index_2*Employment.Bin + Wealth.Index_3*Employment.Bin + Wealth.Index_4*Employment.Bin,
                        family = poisson, weights = wts, data = ipv_match.5)
summary(ipv.M.pois.2)
# Out:
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# Call:
# glm(formula = Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
#     (Husb.Employment.Bin * Employment.Bin) + Age + Region_4 +
#     Region_5 + Region_9 + Region_10 + Region_12 + Region_13 +
#     Region_15 + Educ.Level_2 + Educ.Level_3 + Marital_2 + Husb.Educ.Level_1 +
#     Wealth.Index_2 * Employment.Bin + Wealth.Index_3 * Employment.Bin +
#     Wealth.Index_4 * Employment.Bin, family = poisson, data = ipv_match.5,
#     weights = wts)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.43932  -0.00003  -0.00002  -0.00001   0.80885
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                        -1.775e+01  9.286e+04   0.000    1.000
# Husb.Employment.Bin                 3.138e-01  1.506e+04   0.000    1.000
# Employment.Bin                      4.349e-02  2.087e+04   0.000    1.000
# ...

# %%
#Pseudo R^2
1-(5.8088/47.5620)
# Out:
# [1] 0.8778689

# %%
library(regclass)

VIF(ipv.M.pois.2)
# Out:
#                Husb.Employment.Bin                     Employment.Bin
#                       6.315174e+08                       1.181137e+01
#                                Age                           Region_4
#                       1.221957e+01                       2.621668e+09
#                           Region_5                           Region_9
#                       4.033610e+10                       5.862125e+00
#                          Region_10                          Region_12
#                       1.303637e+01                       9.959343e+09
#                          Region_13                          Region_15
#                       1.800461e+00                       2.594625e+01
#                       Educ.Level_2                       Educ.Level_3
#                       2.453836e+10                       2.096946e+10
#                          Marital_2                  Husb.Educ.Level_1
# ...

# %%
#install.packages('pscl')
#library(pscl)

#pR2(ipv.M.pois)['McFadden'] #i cant make it work sorry

#McFadden Pseudo R^2
1-(133.18/219.18)
# Out:
# [1] 0.3923716

# %%
mean(ipv_match.3$Counts.IPV)
var(ipv_match.3$Counts.IPV)

mean(ipv_match.5$Counts.IPV)
var(ipv_match.5$Counts.IPV)

# mas mataas var kaysa mean
# Out:
# [1] 0.2649573
# [1] 0.3964567
# [1] 0.2184557
# [1] 0.3370927

# %%
length(ipv_match.2$X)
length(ipv_match.3$X)

table(ipv_match.2$Employment.Bin)
table(ipv_match.2$Husb.Employment.Bin)
table(ipv_match.3$Employment.Bin)
table(ipv_match.3$Husb.Employment.Bin)

length(ipv_match.4$X)
length(ipv_match.5$X)
table(ipv_match.4$Employment.Bin)
table(ipv_match.4$Husb.Employment.Bin)
table(ipv_match.5$Employment.Bin)
table(ipv_match.5$Husb.Employment.Bin)
# Out:
# [1] 561
# [1] 468
#   0   1
# 345 216
#   0   1
#  79 482
#   0   1
# 283 185
#   0   1
#  63 405
# [1] 3404
# [1] 531
#    0    1
# 1923 1481
#    0    1
#   71 3333
#   0   1
# 312 219
#   0   1
#  68 463

# %%
counts.3.1 <- ipv_match.3[ipv_match.3$Husb.Employment.Bin == 1, ]
counts.3 <- ipv_match.3[ipv_match.3$Husb.Employment.Bin == 0, ]
counts.5.1 <- ipv_match.5[ipv_match.5$Husb.Employment.Bin == 1, ]
counts.5 <- ipv_match.5[ipv_match.5$Husb.Employment.Bin == 0, ]
var(counts.3.1$Counts.IPV)
var(counts.3$Counts.IPV)
var(counts.5.1$Counts.IPV)
var(counts.5$Counts.IPV)
# Out:
# [1] 0.3917247
# [1] 0.4331797
# [1] 0.3192804
# [1] 0.4554434

# %% [markdown]
# Negative binomial

# %%
install.packages("lmtest")
library(lmtest)
# Out:
# Installing package into ‘/work/.R/library’
# (as ‘lib’ is unspecified)
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#
# Attaching package: ‘lmtest’
#
#
# The following object is masked from ‘package:VGAM’:
#
#     lrtest

# %%
install.packages("MASS")
library(MASS)
# Out:
# Installing package into ‘/work/.R/library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("MASS"):
# “installation of package ‘MASS’ had non-zero exit status”

# %%
head(ipv_match.3)
# Out:
#    X.1 X  RespondentID Year Age Region Educ.Level Educ.Years Educ.Attained
# 4   4   6  7           2017 23  15     3          12         5
# 8   8  10 11           2017 37  15     1           2         1
# 10 10  12 13           2017 23  15     2          10         3
# 11 11  13 14           2017 24  15     1           7         2
# 17 17  23 24           2017 36  15     1           5         1
# 30 30  37 39           2017 35  15     1           7         2
#    Wealth.Index ... Husb.Educ.Level_2 Husb.Educ.Level_3 LPG_Both employed
# 4  4            ... 0                 0                 0
# 8  3            ... 0                 0                 1
# 10 2            ... 1                 0                 0
# 11 1            ... 0                 0                 0
# 17 1            ... 0                 0                 0
# 30 1            ... 0                 0                 0
#    LPG_Both unemployed LPG_Female only Employed LPG_Male only Employed weights
# ...

# %%
install.packages("regclass")
library(regclass)
# Out:
# Installing package into ‘/work/.R/library’
# (as ‘lib’ is unspecified)

# %%
ipv.M.nb <- glm.nb(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + (Husb.Employment.Bin * Employment.Bin) + Age
                            + Region_2 + Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 + Region_10
                            + Region_11 + Region_12 + Region_13 + Region_14 + Region_15 + Region_16 + Region_17 
                            + Educ.Level_1 + Educ.Level_2 + Educ.Level_3 + Marital_2 + 
                            + Husb.Educ.Level_1 + Husb.Educ.Level_2 + Husb.Educ.Level_3, weights = wts, data = ipv_match.3)
summary(ipv.M.nb)
# Out:
# Call:
# glm.nb(formula = Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
#     (Husb.Employment.Bin * Employment.Bin) + Age + Region_2 +
#     Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 +
#     Region_9 + Region_10 + Region_11 + Region_12 + Region_13 +
#     Region_14 + Region_15 + Region_16 + Region_17 + Educ.Level_1 +
#     Educ.Level_2 + Educ.Level_3 + Marital_2 + +Husb.Educ.Level_1 +
#     Husb.Educ.Level_2 + Husb.Educ.Level_3, data = ipv_match.3,
#     weights = wts, init.theta = 1.563033019, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0124  -0.6944  -0.3375  -0.1106   3.2819
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                        -3.708e+01  3.169e+07   0.000  1.00000
# Husb.Employment.Bin                 5.843e-01  5.690e-01   1.027  0.30449
# Employment.Bin                      1.040e+00  6.445e-01   1.613  0.10666
# ...

# %%
ipv.M.nb3 <- glm.nb(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + (Husb.Employment.Bin * Employment.Bin) + Age
                            + Region_2 + Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 + Region_10
                            + Region_11 + Region_12 + Region_13 + Region_15 + Region_16 + Region_17 
                            + Educ.Level_1 + Educ.Level_2 + Educ.Level_3 + Marital_2 + 
                            + Husb.Educ.Level_1 + Husb.Educ.Level_2, weights = wts, data = ipv_match.3)
summary(ipv.M.nb3)
VIF(ipv.M.nb3)
# Out:
# Call:
# glm.nb(formula = Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
#     (Husb.Employment.Bin * Employment.Bin) + Age + Region_2 +
#     Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 +
#     Region_9 + Region_10 + Region_11 + Region_12 + Region_13 +
#     Region_15 + Region_16 + Region_17 + Educ.Level_1 + Educ.Level_2 +
#     Educ.Level_3 + Marital_2 + +Husb.Educ.Level_1 + Husb.Educ.Level_2,
#     data = ipv_match.3, weights = wts, init.theta = 1.452281332,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0384  -0.6819  -0.3413  -0.1274   3.2721
#
# Coefficients:
#                                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)                        -1.554316   1.430100  -1.087   0.2771
# Husb.Employment.Bin                 0.521179   0.570244   0.914   0.3607
# Employment.Bin                      0.989297   0.646105   1.531   0.1257
# ...

# %%
ipv.M.nb2 <- glm.nb(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + (Husb.Employment.Bin * Employment.Bin) + Age
                            + Region_2 + Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 + Region_9 + Region_10
                            + Region_11 + Region_12 + Region_13 + Region_14 + Region_15 + Region_16 + Region_17 
                            + Educ.Level_1 + Educ.Level_2 + Educ.Level_3 + Marital_2 + 
                            + Husb.Educ.Level_1 + Husb.Educ.Level_2 + Husb.Educ.Level_3, weights = wts, data = ipv_match.5)
summary(ipv.M.nb2)
# Out:
# Call:
# glm.nb(formula = Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
#     (Husb.Employment.Bin * Employment.Bin) + Age + Region_2 +
#     Region_3 + Region_4 + Region_5 + Region_6 + Region_7 + Region_8 +
#     Region_9 + Region_10 + Region_11 + Region_12 + Region_13 +
#     Region_14 + Region_15 + Region_16 + Region_17 + Educ.Level_1 +
#     Educ.Level_2 + Educ.Level_3 + Marital_2 + +Husb.Educ.Level_1 +
#     Husb.Educ.Level_2 + Husb.Educ.Level_3, data = ipv_match.5,
#     weights = wts, init.theta = 0.8973803846, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.3818  -0.6147  -0.4009  -0.2537   2.4840
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         1.235e+00  2.099e+00   0.588   0.5563
# Husb.Employment.Bin                 2.192e-01  5.785e-01   0.379   0.7047
# Employment.Bin                      9.577e-01  6.581e-01   1.455   0.1456
# ...

# %%
### scratch
aggregate(ipv_match.3$Counts.IPV, list(ipv_match.3$Husb.Employment.Bin), FUN = mean)
aggregate(ipv_match.3$Counts.IPV, list(ipv_match.3$Employment.Bin), FUN = mean)

# mas mababa talaga IPV pag male employed (1); and mas mataas pag female emloyed (1)
# Out:
#   Group.1 x
# 1 0       0.2857143
# 2 1       0.2617284
#   Group.1 x
# 1 0       0.2155477
# 2 1       0.3405405

# %%
### scratch
#install.packages("pscl")
#library(pscl)
ipv.zinb <- zeroinfl(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + Age + Region + Educ.Level + Marital + Husb.Age + Husb.Educ.Level, weights = wts, link = "logit", dist = "negbin", data = ipv_match.3)
summary(ipv.zinb) # pangit
# Out:
# Error in zeroinfl(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + : could not find function "zeroinfl"
# Traceback:

# %% [markdown]
# Dataset

# %%
head(ipv_match)
# Out:
# Error in head(ipv_match): object 'ipv_match' not found
# Traceback:
#
# 1. head(ipv_match)

# %% [markdown]
# Reclassifying variables

# %%
ipv$Marital <- factor(ipv$Marital)
ipv$Husb.Educ.Level <- factor(ipv$Husb.Educ.Level)
ipv$Region <- factor(ipv$Region)
ipv$LPG <- relevel(factor(ipv$LPG), ref = "Male only Employed")
# Out:
# Error in factor(ipv$Marital): object 'ipv' not found
# Traceback:
#
# 1. factor(ipv$Marital)

# %% [markdown]
# Descriptives

# %%
aggregate(ipv$Counts.IPV, list(ipv$LPG), FUN = mean) 
aggregate(ipv$Counts.IPV, list(ipv$LPG), FUN = sum)
aggregate(ipv$Counts.IPV, list(ipv$LPG), FUN = length)
table(ipv$Counts.IPV)
# Out:
#   Group.1              x
# 1 Male only Employed   0.3714794
# 2 Both employed        0.4312743
# 3 Both unemployed      0.4838710
# 4 Female only Employed 0.6666667
#   Group.1              x
# 1 Male only Employed   2295
# 2 Both employed        2325
# 3 Both unemployed        45
# 4 Female only Employed   72
#   Group.1              x
# 1 Male only Employed   6178
# 2 Both employed        5391
# 3 Both unemployed        93
# 4 Female only Employed  108
#    0    1    2    3    9   10   19
# 8613 1929  905  320    1    1    1

# %% [markdown]
# Poisson Fit

# %%
summary(ipv.M.pois)
# Out:
# Error in summary(ipv.M.pois): object 'ipv.M.pois' not found
# Traceback:
#
# 1. summary(ipv.M.pois)

# %%
ipv.pois <- glm(Counts.IPV ~ LPG + Husb.Educ.Level + Region + Age 
                    + Marital, family = poisson, data = ipv)
summary(ipv.pois)
# Out:
# Call:
# glm(formula = Counts.IPV ~ LPG + Husb.Educ.Level + Region + Age +
#     Marital, family = poisson, data = ipv)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.5596  -0.9207  -0.7786   0.4405   9.9094
#
# Coefficients:
#                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -1.506658   0.153106  -9.841  < 2e-16 ***
# LPGBoth employed         0.177891   0.030218   5.887 3.93e-09 ***
# LPGBoth unemployed       0.324623   0.151341   2.145 0.031955 *
# LPGFemale only Employed  0.753327   0.120418   6.256 3.95e-10 ***
# Husb.Educ.Level1         0.436183   0.117769   3.704 0.000212 ***
# Husb.Educ.Level2         0.353375   0.117723   3.002 0.002684 **
# Husb.Educ.Level3         0.054031   0.120438   0.449 0.653707
# Region2                  0.189722   0.100522   1.887 0.059110 .
# Region3                 -0.059849   0.092684  -0.646 0.518450
# Region4                  0.204807   0.099461   2.059 0.039477 *
# ...

# %%
# Intercept-only (Poisson)
ipv.int <- glm(Counts.IPV ~ 1, family = poisson, data = ipv)

# %% [markdown]
# Diagnostics of the Poisson Fit

# %%
# Goodness-of-Fit

# install.packages("lmtest")
library(lmtest)
lrtest(ipv.int, ipv.pois)
# Out:
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#   #Df LogLik    Df Chisq    Pr(>Chisq)
# 1  1  -10316.29 NA       NA           NA
# 2 27  -10031.09 26 570.3927 8.72532e-104

# %%
# Multicollinearity

# install.packages("regclass")
library(regclass)
VIF(ipv.pois)
# Out:
# Loading required package: bestglm
#
# Loading required package: leaps
#
# Loading required package: VGAM
#
# Loading required package: stats4
#
# Loading required package: splines
#
# Loading required package: rpart
#
# Loading required package: randomForest
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
# Important regclass change from 1.3:
# All functions that had a . in the name now have an _
# all.correlations -> all_correlations, cor.demo -> cor_demo, etc.
# Error in h(simpleError(msg, call)): error in evaluating the argument 'object' in selecting a method for function 'coef': object 'ipv.pois' not found
# Traceback:
#
# 1. VIF(ipv.pois)
# 2. coef(mod)
# 3. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "object 'ipv.pois' not found",
#  .     base::quote(coef(mod)))
# 4. h(simpleError(msg, call))

# %%
# Test for Overdispersion
mean(ipv$Counts.IPV)
var(ipv$Counts.IPV)

# install.packages("AER")
library(AER)
dispersiontest(ipv.pois, alternative = "greater")

# for some reason, di gumagana AER dito. pero significant yung dispersion test sa R, 
# thus overdispersed
# Out:
# Error in mean(ipv$Counts.IPV): object 'ipv' not found
# Traceback:
#
# 1. mean(ipv$Counts.IPV)

# %% [markdown]
# Negative Binomial Fit

# %%
install.packages("MASS")
library(MASS)
# Out:
# Installing package into ‘/work/.R/library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("MASS"):
# “installation of package ‘MASS’ had non-zero exit status”

# %%
ipv.nb <- glm.nb(Counts.IPV ~ LPG + Husb.Educ.Level + Region + Age + Marital,
                     data = ipv)
summary(ipv.nb)
# Out:
# Error in is.data.frame(data): object 'ipv' not found
# Traceback:
#
# 1. glm.nb(Counts.IPV ~ LPG + Husb.Educ.Level + Region + Age + Marital,
#  .     data = ipv)
# 2. eval.parent(mf)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. stats::model.frame(formula = Counts.IPV ~ LPG + Husb.Educ.Level +
#  .     Region + Age + Marital, data = ipv, drop.unused.levels = TRUE)
# 6. model.frame.default(formula = Counts.IPV ~ LPG + Husb.Educ.Level +
#  .     Region + Age + Marital, data = ipv, drop.unused.levels = TRUE)
# 7. is.data.frame(data)

# %% [markdown]
# Variable Selection (Backward Elimination)

# %%
# no marital
ipv.nb_no.marital <- glm.nb(Counts.IPV ~ LPG + Husb.Educ.Level + Region + Age,
                            data = ipv)
summary(ipv.nb_no.marital)
anova(ipv.nb, ipv.nb_no.marital)
# Out:
# Call:
# glm.nb(formula = Counts.IPV ~ LPG + Husb.Educ.Level + Region +
#     Age, data = ipv, init.theta = 0.8317616282, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.1780  -0.8358  -0.7310   0.3510   5.6967
#
# Coefficients:
#                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -1.162975   0.178022  -6.533 6.46e-11 ***
# LPGBoth employed         0.170522   0.037155   4.589 4.44e-06 ***
# LPGBoth unemployed       0.406696   0.190560   2.134  0.03283 *
# LPGFemale only Employed  0.731168   0.163110   4.483 7.37e-06 ***
# Husb.Educ.Level1         0.436534   0.139071   3.139  0.00170 **
# Husb.Educ.Level2         0.364565   0.138934   2.624  0.00869 **
# Husb.Educ.Level3         0.041946   0.141931   0.296  0.76758
# Region2                  0.127305   0.119630   1.064  0.28726
# Region3                 -0.076898   0.108950  -0.706  0.48030
# Region4                  0.199779   0.119898   1.666  0.09566 .
# ...

# %%
# no educ
ipv.nb_no.educ <- glm.nb(Counts.IPV ~ LPG + Region + Age + Marital,
                         data = ipv)
summary(ipv.nb_no.educ)
anova(ipv.nb, ipv.nb_no.educ)
# Out:
# Call:
# glm.nb(formula = Counts.IPV ~ LPG + Region + Age + Marital, data = ipv,
#     init.theta = 0.8308208578, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.2370  -0.8243  -0.7328   0.3348   5.6547
#
# Coefficients:
#                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -1.232524   0.117860 -10.458  < 2e-16 ***
# LPGBoth employed         0.163432   0.037050   4.411 1.03e-05 ***
# LPGBoth unemployed       0.242919   0.190619   1.274 0.202534
# LPGFemale only Employed  0.654503   0.162523   4.027 5.65e-05 ***
# Region2                  0.196701   0.119899   1.641 0.100891
# Region3                 -0.029983   0.108949  -0.275 0.783161
# Region4                  0.237549   0.119336   1.991 0.046526 *
# Region5                  0.331170   0.101255   3.271 0.001073 **
# Region6                  0.063700   0.104231   0.611 0.541108
# Region7                  0.620469   0.105362   5.889 3.89e-09 ***
# ...

# %%
# no region
ipv.nb_no.region <- glm.nb(Counts.IPV ~ LPG + Husb.Educ.Level + Age + Marital,
                 data = ipv)
summary(ipv.nb_no.region)
anova(ipv.nb, ipv.nb_no.region)
# Out:
# Call:
# glm.nb(formula = Counts.IPV ~ LPG + Husb.Educ.Level + Age + Marital,
#     data = ipv, init.theta = 0.7913546377, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.1873  -0.8193  -0.7497   0.3824   5.2429
#
# Coefficients:
#                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -1.277461   0.162587  -7.857 3.93e-15 ***
# LPGBoth employed         0.200678   0.037027   5.420 5.97e-08 ***
# LPGBoth unemployed       0.274037   0.192905   1.421  0.15544
# LPGFemale only Employed  0.722459   0.163389   4.422 9.79e-06 ***
# Husb.Educ.Level1         0.421378   0.137895   3.056  0.00224 **
# Husb.Educ.Level2         0.319263   0.137270   2.326  0.02003 *
# Husb.Educ.Level3         0.019293   0.140161   0.138  0.89052
# Age                     -0.004587   0.002840  -1.615  0.10634
# Marital2                 0.367561   0.040186   9.147  < 2e-16 ***
# ---
# ...

# %%
# no age
ipv.nb_no.age <- glm.nb(Counts.IPV ~ LPG + Husb.Educ.Level + Region + Marital,
                 data = ipv)
summary(ipv.nb_no.age)
anova(ipv.nb, ipv.nb_no.age)
# Out:
# Call:
# glm.nb(formula = Counts.IPV ~ LPG + Husb.Educ.Level + Region +
#     Marital, data = ipv, init.theta = 0.8581988372, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.2196  -0.8309  -0.7201   0.3259   5.5380
#
# Coefficients:
#                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -1.67611    0.15777 -10.624  < 2e-16 ***
# LPGBoth employed         0.16449    0.03654   4.501 6.76e-06 ***
# LPGBoth unemployed       0.34485    0.19052   1.810  0.07029 .
# LPGFemale only Employed  0.72888    0.16225   4.492 7.04e-06 ***
# Husb.Educ.Level1         0.44236    0.13855   3.193  0.00141 **
# Husb.Educ.Level2         0.36418    0.13833   2.633  0.00847 **
# Husb.Educ.Level3         0.06109    0.14138   0.432  0.66564
# Region2                  0.20587    0.11973   1.719  0.08554 .
# Region3                 -0.04752    0.10882  -0.437  0.66232
# Region4                  0.22620    0.11930   1.896  0.05796 .
# ...

# %% [markdown]
# All factors contribute significantly to the model. The final model is the NB model.

# %%
# Intercept-only (NB)
ipv.int.nb <- glm.nb(Counts.IPV ~ 1, data = ipv)

# %% [markdown]
# Diagnostics of the Final Fit

# %%
# Goodness-of-Fit
anova(ipv.nb, ipv.int.nb) # pwede ring lrtest() pero di gumagana here
# Out:
#   Model                                          theta     Resid. df
# 1 1                                              0.7131244 11769
# 2 LPG + Husb.Educ.Level + Region + Age + Marital 0.8596209 11743
#      2 x log-lik. Test      df LR stat. Pr(Chi)
# 1 -19753.07              NA          NA NA
# 2 -19372.03       1 vs 2 26    381.0407  0

# %%
# Multicollinearity
VIF(ipv.nb)
# Out:
# Error in h(simpleError(msg, call)): error in evaluating the argument 'object' in selecting a method for function 'coef': object 'ipv.nb' not found
# Traceback:
#
# 1. VIF(ipv.nb)
# 2. coef(mod)
# 3. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "object 'ipv.nb' not found",
#  .     base::quote(coef(mod)))
# 4. h(simpleError(msg, call))

# %% [markdown]
# ## Logistic Regression Analysis (try lang)

# %% [markdown]
# Data Preparation

# %%
ipv_log <- ipv_match.3
val <- c(2, 3, 9, 10, 19)

ipv3["Counts.IPV"] <- sapply(ipv3["Counts.IPV"], 
                             function(x) replace(x, x %in% val, 1))

# %%
ipv_log <- ipv_match.3
val <- c(1,2,3)
ipv_log["Counts.IPV"] <- sapply(ipv_log["Counts.IPV"], 
                             function(x) replace(x, x %in% val, 1))

# %%
aggregate(ipv_log$Counts.IPV, list(ipv_log$Husb.Employment.Bin), FUN = mean)
# Out:
#   Group.1 Counts.IPV
# 1 0       0.1578947
# 2 1       0.1176471

# %% [markdown]
# Logistic Fit

# %%
ipv_log.fit <- glm(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
    Age + Region + Educ.Level + Marital + Husb.Age + Husb.Educ.Level, data = ipv_log)
summary(ipv_log.fit)
# Out:
# Call:
# glm(formula = Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
#     Age + Region + Educ.Level + Marital + Husb.Age + Husb.Educ.Level,
#     data = ipv_log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -0.40895  -0.17636  -0.07366   0.05117   0.87154
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -0.91970    0.45116  -2.039   0.0475 *
# Husb.Employment.Bin -0.02064    0.09822  -0.210   0.8345
# Employment.Bin       0.11441    0.09549   1.198   0.2373
# Age                 -0.02605    0.02952  -0.882   0.3824
# Region               0.01108    0.00984   1.126   0.2663
# Educ.Level           0.05557    0.14370   0.387   0.7009
# Marital              0.20909    0.14025   1.491   0.1432
# Husb.Age             0.04144    0.02611   1.587   0.1197
# Husb.Educ.Level     -0.02709    0.12119  -0.224   0.8242
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %%
ipv_log2 <- ipv_match.5
val <- c(1,2)
ipv_log2["Counts.IPV"] <- sapply(ipv_log2["Counts.IPV"], 
                             function(x) replace(x, x %in% val, 1))

# %%
ipv_log.fit2 <- glm(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
    Age + Region + Educ.Level + Marital + Husb.Age + Husb.Educ.Level, data = ipv_log2)
summary(ipv_log.fit2)
# Out:
# Call:
# glm(formula = Counts.IPV ~ Husb.Employment.Bin + Employment.Bin +
#     Age + Region + Educ.Level + Marital + Husb.Age + Husb.Educ.Level,
#     data = ipv_log2)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -0.51949  -0.21239  -0.09046   0.02377   0.83030
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -0.324678   0.385718  -0.842   0.4033
# Husb.Employment.Bin  0.126165   0.096571   1.306   0.1965
# Employment.Bin       0.166545   0.095000   1.753   0.0848 .
# Age                 -0.058015   0.026487  -2.190   0.0325 *
# Region               0.006945   0.010127   0.686   0.4955
# Educ.Level           0.244086   0.153217   1.593   0.1165
# Marital              0.007638   0.115319   0.066   0.9474
# Husb.Age             0.054885   0.024757   2.217   0.0305 *
# Husb.Educ.Level     -0.147206   0.126209  -1.166   0.2482
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %%
colnames(ipv3)
# Out:
#  [1] "X.1"                 "X"                   "RespondentID"
#  [4] "Year"                "Age"                 "Region"
#  [7] "Educ.Level"          "Educ.Years"          "Educ.Attained"
# [10] "Marital"             "Husb.Educ.Level"     "Husb.Educ.Years"
# [13] "Husb.Employment"     "Employment"          "Husb.Educ.Attained"
# [16] "Husb.Age"            "Emotional.IPV"       "Less.Physic.IPV"
# [19] "More.Physic.IPV"     "Sexual.IPV"          "Husb.Employment.Bin"
# [22] "Employment.Bin"      "LPG"                 "Physical.IPV"
# [25] "ANY.IPV"             "Counts.IPV"          "Male"
# [28] "Female"

# %%
aggregate(ipv_match.3$Emotional.IPV, list(ipv_match.3$Husb.Employment.Bin), FUN = mean)
aggregate(ipv_match.5$Emotional.IPV, list(ipv_match.5$Husb.Employment.Bin), FUN = mean)
aggregate(ipv_match.3$Emotional.IPV, list(ipv_match.3$Employment.Bin), FUN = mean)
aggregate(ipv_match.5$Emotional.IPV, list(ipv_match.5$Employment.Bin), FUN = mean)
# Out:
#   Group.1 x
# 1 0       0.1052632
# 2 1       0.1176471
#   Group.1 x
# 1 0       0.0400000
# 2 1       0.1860465
#   Group.1 x
# 1 0       0.03846154
# 2 1       0.18518519
#   Group.1 x
# 1 0       0.05263158
# 2 1       0.23333333
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#      X.1  X     RespondentID Year Age Region Educ.Level Educ.Years
# 80     80  9314  9815        2017 25   9     3          14
# 85     85  9319  9820        2017 25   9     3          15
# 355   355  9619 10131        2017 40  15     3          12
# 366   366  9636 10148        2017 40  15     3          15
# 665   665 10000 10530        2017 40  16     1           5
# 676   676 10014 10544        2017 29  16     3          13
# 787   787 10148 10678        2017 30  16     2          11
# ...

# %%
ipv0 <- ipv_match.3
# library(dplyr)
mutate(ipv0, inter = Husb.Employment.Bin*Employment.Bin)
# Out:
#      X.1  X     RespondentID Year Age Region Educ.Level Educ.Years
# 80     80  9314  9815        2017 25   9     3          14
# 85     85  9319  9820        2017 25   9     3          15
# 355   355  9619 10131        2017 40  15     3          12
# 366   366  9636 10148        2017 40  15     3          15
# 665   665 10000 10530        2017 40  16     1           5
# 676   676 10014 10544        2017 29  16     3          13
# 787   787 10148 10678        2017 30  16     2          11
# 958   958 10361 10900        2017 25  13     3          12
# 962   962 10365 10904        2017 23  13     3          13
# 1037 1037 10462 11010        2017 25  13     3          12
# 1145 1145 10592 11147        2017 25  13     3          14
# 1172 1172 10624 11179        2017 22  13     3          14
# 1194 1194 10648 11207        2017 23  13     3          12
# 1479 1479 10982 11560        2017 21   2     3          13
# 1608 1608 11145 11731        2017 21   2     3          13
# ...

# %%
ipv_nb <- glm(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + inter +
    Age + Region + Educ.Level + Marital + Husb.Age + Husb.Educ.Level, data = ipv0)
# Out:
# Error in eval(predvars, data, env): object 'inter' not found
# Traceback:
#
# 1. glm(Counts.IPV ~ Husb.Employment.Bin + Employment.Bin + inter +
#  .     Age + Region + Educ.Level + Marital + Husb.Age + Husb.Educ.Level,
#  .     data = ipv0)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = Counts.IPV ~ Husb.Employment.Bin +
#  .     Employment.Bin + inter + Age + Region + Educ.Level + Marital +
#  .     Husb.Age + Husb.Educ.Level, data = ipv0, drop.unused.levels = TRUE)
# 5. model.frame.default(formula = Counts.IPV ~ Husb.Employment.Bin +
#  .     Employment.Bin + inter + Age + Region + Educ.Level + Marital +
#  .     Husb.Age + Husb.Educ.Level, data = ipv0, drop.unused.levels = TRUE)
# 6. eval(predvars, data, env)
# 7. eval(predvars, data, env)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8672f010-76e5-4fe5-a087-2513d801c0e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
