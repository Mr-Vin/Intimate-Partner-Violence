# %%
campers.ipv <- read.csv("/work/campers_ipv_wealth.csv")

# %% [markdown]
# Important Demographics:
#
# V012	Respondent's current age
# V013	Age in 5-year groups
# V024	Region
# V106	Highest educational level
# V149	Educational attainment
# V190	Wealth index combined
# V191	Wealth index factor score combined (5 decimals)
# V190A	Wealth index for urban/rural
# V191A	Wealth index factor score for urban/rural (5 decimals)
#
# V501	Current marital status
# V502	Currently/formerly/never in union
#
# V701	Husband/partner's education level
# V704	Husband/partner's occupation
# V705	Husband/partner's occupation (grouped)
# V714	Respondent currently working
# V716	Respondent's occupation
# V717	Respondent's occupation (grouped)
# V729	Husband/partner's educational attainment
# V730	Husband/partner's age
# V731	Respondent worked in last 12 months

# %%
# Remove rows with missing important demographics since they may
# be attributed to measurement or recording errors

demographics <- c("V012", "V013", "V024", "V106","V149","V190","V190A","V501", "V502", "V701", "V704", "V705", 
"V714", "V716", "V717", "V729", "V730", "V731")

# %%
campers.ipv.clean <- campers.ipv[complete.cases(campers.ipv[, demographics]), ]

# %%
# measure how many data were removed

nrow(campers.ipv)
nrow(campers.ipv.clean)
# Out:
# [1] 5201
# [1] 5038

# %% [markdown]
# ##### V106_VS1	Highest educational level
# 		No education	0
# 		Primary	1
# 		Secondary	2
# 		Higher	3
# 		Don't know	8
# 		Missing	9		Missing
#
# ##### V501_VS1	Current marital status
# 		Never in union	0
# 		Married	1
# 		Living with partner	2
# 		Widowed	3
# 		Divorced	4
# 		No longer living together/separated	5
# 		Missing	9		Missing
#
# ##### V701_VS1	Husband/partner's education level
# 		No education	0
# 		Primary	1
# 		Secondary	2
# 		Higher	3
# 		Don't know	8
# 		Missing	9		Missing
# 		Not applicable	 		Not Applicable
#
# ##### V704_VS1	Husband/partner's occupation
# 		Not working and didn't work in last 12 months	0
# 			1	9995
# 		Other	9996
# 		Don't know	9998
# 		Missing	9999		Missing
# 		Not applicable	    		Not Applicable
#
# ##### V716_VS1	Respondent's occupation
# 		Not working and didn't work in last 12 months	0
# 			1	9995
# 		Other	9996
# 		Don't know	9998
# 		Missing	9999		Missing
# 		Not applicable	    		Not Applicable
#
# ##### V730_VS1	Husband/partner's age
# 			15	95
# 		96+	96
# 			97
# 		Don't know	98
# 		Missing	99		Missing
# 		Not applicable	  		Not Applicable

# %%
# Remove rows with values of variables categorized as 'missing' or 'don't know' 
# since they provide incomplete information, and therefore may affect accuracy of estimates

campers.ipv.final.data <- campers.ipv.clean[
    campers.ipv.clean$V106 < 8 &
    campers.ipv.clean$V501 < 9 &
    campers.ipv.clean$V701 < 8 &
    campers.ipv.clean$V704 < 9998 &
    campers.ipv.clean$V716 < 9998 &
    campers.ipv.clean$V730 < 98,
    -c(1)
]

# %%
# measure how many data were removed

nrow(campers.ipv)
nrow(campers.ipv.clean)
nrow(campers.ipv.final.data)
ncol(campers.ipv.final.data)

# Final Number of Observations: 14232 women respondents
# Out:
# [1] 5201
# [1] 5038
# [1] 5009
# [1] 117

# %%
View(campers.ipv.final.data)
# Out:
#      CASEID          V000 V001 V002 V003 V004 V005    V006 V007 V008 ... D110D
# 1        00010007  2 PH7  1     7   2    1    361799   8   2017 1412 ... NA
# 2        00010010  2 PH7  1    10   2    1    361799   8   2017 1412 ... NA
# 3        00010013  2 PH7  1    13   2    1    361799   8   2017 1412 ... NA
# 5        00010015  7 PH7  1    15   7    1    361799   8   2017 1412 ... NA
# 6        00010018  9 PH7  1    18   9    1    361799   8   2017 1412 ... NA
# 7        00010022  4 PH7  1    22   4    1    361799   8   2017 1412 ... NA
# 8        00010025  2 PH7  1    25   2    1    361799   8   2017 1412 ... NA
# 9        00010029  2 PH7  1    29   2    1    361799   8   2017 1412 ... NA
# 10       00020007  2 PH7  2     7   2    2    416591   8   2017 1412 ... NA
# 11       00020016  2 PH7  2    16   2    2    416591   8   2017 1412 ... NA
# 12       00020018  2 PH7  2    18   2    2    416591   8   2017 1412 ... NA
# 13       00020019  9 PH7  2    19   9    2    416591   8   2017 1412 ... NA
# 14       00020026  2 PH7  2    26   2    2    416591   8   2017 1412 ... NA
# 15       00030006  2 PH7  3     6   2    3    207861   9   2017 1413 ... NA
# 16       00030007  6 PH7  3     7   6    3    207861   9   2017 1413 ... NA
# 17       00030007  9 PH7  3     7   9    3    207861   9   2017 1413 ... NA
# 18       00030010  2 PH7  3    10   2    3    207861   9   2017 1413 ... NA
# 19       00030011  2 PH7  3    11   2    3    207861   9   2017 1413 ... NA
# 20       00030012  5 PH7  3    12   5    3    207861   9   2017 1413 ... NA
# 21       00030021  6 PH7  3    21   6    3    207861   9   2017 1413 ... NA
# 22       00030021  9 PH7  3    21   9    3    207861   9   2017 1413 ... NA
# 23       00030022  2 PH7  3    22   2    3    207861   9   2017 1413 ... NA
# 24       00040001  2 PH7  4     1   2    4    366148  10   2017 1414 ... NA
# 25       00040002  2 PH7  4     2   2    4    366148  10   2017 1414 ... NA
# 26       00040007  4 PH7  4     7   4    4    366148  10   2017 1414 ... NA
# 27       00040011  2 PH7  4    11   2    4    366148  10   2017 1414 ... NA
# 28       00040012  2 PH7  4    12   2    4    366148  10   2017 1414 ... NA
# 29       00040019  2 PH7  4    19   2    4    366148  10   2017 1414 ... NA
# 30       00040022  1 PH7  4    22   1    4    366148  10   2017 1414 ... NA
# 31       00040023  2 PH7  4    23   2    4    366148  10   2017 1414 ...  0
# ...  ...             ...  ...  ...  ...  ...  ...     ...  ...  ...      ...
# 5172     12460015  2 PH7  1246 15    2   1246 1090744 9    2017 1413 ...  0
# 5173     12460025  6 PH7  1246 25    6   1246 1090744 8    2017 1412 ... NA
# 5174     12470004  2 PH7  1247  4    2   1247  564460 9    2017 1413 ... NA
# 5175     12470005  2 PH7  1247  5    2   1247  564460 9    2017 1413 ... NA
# 5176     12470007  2 PH7  1247  7    2   1247  564460 9    2017 1413 ... NA
# 5177     12470010  2 PH7  1247 10    2   1247  564460 9    2017 1413 ...  0
# 5178     12470015  2 PH7  1247 15    2   1247  564460 9    2017 1413 ... NA
# 5179     12470017  2 PH7  1247 17    2   1247  564460 9    2017 1413 ... NA
# 5180     12470018  2 PH7  1247 18    2   1247  564460 9    2017 1413 ... NA
# 5181     12470026  2 PH7  1247 26    2   1247  564460 9    2017 1413 ... NA
# 5182     12480011  2 PH7  1248 11    2   1248  272686 9    2017 1413 ... NA
# 5183     12480014  8 PH7  1248 14    8   1248  272686 9    2017 1413 ... NA
# 5184     12480023 10 PH7  1248 23   10   1248  272686 9    2017 1413 ... NA
# 5185     12480026  2 PH7  1248 26    2   1248  272686 9    2017 1413 ... NA
# 5186     12490002  3 PH7  1249  2    3   1249  872595 9    2017 1413 ... NA
# 5187     12490011  2 PH7  1249 11    2   1249  872595 9    2017 1413 ... NA
# 5188     12490015  2 PH7  1249 15    2   1249  872595 9    2017 1413 ... NA
# 5189     12490017  2 PH7  1249 17    2   1249  872595 9    2017 1413 ... NA
# 5190     12490019  2 PH7  1249 19    2   1249  872595 9    2017 1413 ... NA
# 5191     12490020  2 PH7  1249 20    2   1249  872595 9    2017 1413 ... NA
# 5192     12500002  2 PH7  1250  2    2   1250 1227087 8    2017 1412 ... NA
# 5193     12500006  2 PH7  1250  6    2   1250 1227087 8    2017 1412 ... NA
# 5194     12500009  2 PH7  1250  9    2   1250 1227087 8    2017 1412 ... NA
# 5195     12500012  2 PH7  1250 12    2   1250 1227087 8    2017 1412 ... NA
# 5196     12500016  2 PH7  1250 16    2   1250 1227087 8    2017 1412 ... NA
# 5197     12500018  2 PH7  1250 18    2   1250 1227087 8    2017 1412 ... NA
# 5198     12500020  2 PH7  1250 20    2   1250 1227087 8    2017 1412 ... NA
# 5199     12500022  2 PH7  1250 22    2   1250 1227087 8    2017 1412 ... NA
# 5200     12500024  2 PH7  1250 24    2   1250 1227087 8    2017 1412 ... NA
# 5201     12500026  2 PH7  1250 26    2   1250 1227087 8    2017 1412 ... NA
#      D110E D110F D110G D110H D111 D112 D112A D113 D114
# 1    NA    NA    NA    NA     0    0   NA     0   NA
# 2    NA    NA    NA    NA     0    0   NA     0   NA
# 3    NA    NA    NA    NA     0    0   NA     0   NA
# 5    NA    NA    NA    NA    NA   NA   NA    NA   NA
# 6    NA    NA    NA    NA    NA   NA   NA    NA   NA
# 7    NA    NA    NA    NA     0    0   NA     0   NA
# 8    NA    NA    NA    NA     0    0   NA     0   NA
# 9    NA    NA    NA    NA     0    0   NA     0   NA
# 10   NA    NA    NA    NA     0    0   NA     0   NA
# 11   NA    NA    NA    NA     0    0   NA     0   NA
# 12   NA    NA    NA    NA     0    0   NA     0   NA
# 13   NA    NA    NA    NA     0    0   NA     0   NA
# 14   NA    NA    NA    NA     0    0   NA     0   NA
# 15   NA    NA    NA    NA     0    0   NA     0   NA
# 16   NA    NA    NA    NA     0    0   NA     0   NA
# 17   NA    NA    NA    NA    NA   NA   NA    NA   NA
# 18   NA    NA    NA    NA    NA   NA   NA    NA   NA
# 19   NA    NA    NA    NA     0    0   NA     0   NA
# 20   NA    NA    NA    NA    NA   NA   NA    NA   NA
# 21   NA    NA    NA    NA     0    0   NA     0   NA
# 22   NA    NA    NA    NA    NA   NA   NA    NA   NA
# 23   NA    NA    NA    NA     0    0   NA     0   NA
# 24   NA    NA    NA    NA     0    0   NA     0   NA
# 25   NA    NA    NA    NA     0    0   NA     0   NA
# 26   NA    NA    NA    NA    NA   NA   NA    NA   NA
# 27   NA    NA    NA    NA     0    0   NA     0   NA
# 28   NA    NA    NA    NA     0    0   NA     0   NA
# 29   NA    NA    NA    NA     0    0   NA     0   NA
# 30   NA    NA    NA    NA     0    0   NA     0   NA
# 31    0     1     0    NA     1    0   NA     0   NA
# ...  ...   ...   ...   ...   ...  ...  ...   ...  ...
# 5172  0     0     0    NA     0    1    2     1    2
# 5173 NA    NA    NA    NA     0    0   NA     1    2
# 5174 NA    NA    NA    NA     0    0   NA     0   NA
# 5175 NA    NA    NA    NA     0    0   NA     0   NA
# 5176 NA    NA    NA    NA     0    0   NA     0   NA
# 5177  0     0     0    NA     0    1    2     0   NA
# 5178 NA    NA    NA    NA     0    1    0     0   NA
# 5179 NA    NA    NA    NA     0    0   NA     0   NA
# 5180 NA    NA    NA    NA     0    0   NA     0   NA
# 5181 NA    NA    NA    NA     0    0   NA     0   NA
# 5182 NA    NA    NA    NA     0    0   NA     0   NA
# 5183 NA    NA    NA    NA    NA   NA   NA    NA   NA
# 5184 NA    NA    NA    NA    NA   NA   NA    NA   NA
# 5185 NA    NA    NA    NA     0    0   NA     0   NA
# 5186 NA    NA    NA    NA    NA   NA   NA    NA   NA
# 5187 NA    NA    NA    NA     0    1    0     0   NA
# 5188 NA    NA    NA    NA     0    0   NA     0   NA
# 5189 NA    NA    NA    NA     0    1    2     1    0
# 5190 NA    NA    NA    NA     0    0   NA     1    0
# 5191 NA    NA    NA    NA     0    0   NA     0   NA
# 5192 NA    NA    NA    NA     0    0   NA     1    2
# 5193 NA    NA    NA    NA     0    0   NA     1    1
# 5194 NA    NA    NA    NA     0    0   NA     0   NA
# 5195 NA    NA    NA    NA     0    0   NA     0   NA
# 5196 NA    NA    NA    NA     0    0   NA     0   NA
# 5197 NA    NA    NA    NA     0    0   NA     1    2
# 5198 NA    NA    NA    NA     0    1    2     1    2
# 5199 NA    NA    NA    NA     0    0   NA     1    2
# 5200 NA    NA    NA    NA     0    0   NA     0   NA
# 5201 NA    NA    NA    NA     0    0   NA     1    2

# %%
write.csv(campers.ipv.final.data, "/work/campers_ipv_final_data_wealth.csv")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8672f010-76e5-4fe5-a087-2513d801c0e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
